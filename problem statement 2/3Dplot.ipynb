# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import transforms

# %%
plt.axes(projection='3d')
# Out:
# <Axes3DSubplot:>

# %%
x = []
y = []
z = []

with open("data/IM_0013-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        y.append(float(line.split()[0]))
        z.append(float(line.split()[1]))
        x.append(0.0)
X = np.array(x, dtype=float)
Y = np.array(y, dtype=float)
Z = np.array(z, dtype=float)

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(X, Y, Z)

# %% [markdown]
# ### ax = plt.axes(projection='3d')
# plt.style.use('seaborn')
# x = []
# y = []
# z = []
# with open("data/IM_0008-01_inx.txt", "r") as file:
#     for line in file:
#         point = line.split()
#         z.append(float(line.split()[0]))
#         y.append(float(line.split()[1]))
#         x.append(0.0)
# ax.scatter3D(x, y, z)

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(x, y, z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
#ax.view_init(0,0)
# Out:
# Text(0.5, 0, 'z')

# %%
A = np.array((x, y, z), dtype=float)

# %%
ax = plt.axes(projection= '3d')

# %%
A.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13080/2078266570.py in <module>
# ----> 1 A.shape()
#
# TypeError: 'tuple' object is not callable

# %%
A.shape
# Out:
# (3, 101)

# %%
ax.scatter(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13080/3642971861.py in <module>
# ----> 1 ax.scatter(A)
#
# TypeError: scatter() missing 1 required positional argument: 'ys'

# %%
A[2]
# Out:
# array([107. , 107. , 107. , 107. , 107. , 107. , 107. , 107. , 107. ,
#        107.2, 107.4, 107.6, 107.8, 108. , 108.2, 108.4, 108.6, 108.8,
#        109. , 109.2, 109.6, 110. , 110.2, 110.6, 111. , 112. , 113. ,
#        114. , 115. , 116.4, 118. , 119. , 120. , 121.4, 122.8, 124.2,
#        125.6, 127. , 128.2, 129.6, 131. , 132. , 133. , 133.8, 134.6,
#        135.4, 136.2, 137. , 137.6, 138.4, 139. , 139.8, 140.4, 141.2,
#        142. , 142.6, 143.4, 144. , 144.8, 145.4, 146.2, 147. , 147.4,
#        148. , 148. , 148. , 148. , 148. , 148. , 147.4, 147. , 146. ,
#        145. , 143.6, 142.2, 141. , 139. , 137.2, 135.4, 133.6, 131.6,
#        129.8, 128. , 126.2, 124.2, 122.4, 120.6, 118.8, 117. , 115.4,
#        114. , 113. , 112. , 111. , 110. , 109. , 108.4, 108. , 107.6,
#        107.4, 107.2])
