# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Basal Image

# %%
x_3 = []
y_3 = []
plt.style.use('seaborn')
with open("data/IM_0003-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_3.append(float(line.split()[0])+100)
        y_3.append(float(line.split()[1])+100)
    
# plotting the graph      
plt.style.use('seaborn')
plt.title("Basal Image(SAX) - IM_0003")
plt.plot(x_3, y_3)
plt.plot((x_3[0], x_3[len(x_3)-1]), (y_3[0], y_3[len(y_3)-1]))

# %% [markdown]
# # MID

# %%
x_4 = []
y_4 = []
with open("data/IM_0004-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_4.append(float(line.split()[0]))
        y_4.append(float(line.split()[1]))
    
# plotting the output
plt.style.use('seaborn')
plt.title("MID Image(SAX)- IM_0004")
plt.plot(x_4, y_4)
plt.plot((x_4[0], x_4[len(x_4)-1]), (y_4[0], y_4[len(y_4)-1]))

# %% [markdown]
# # Apical

# %%
x_5 = []
y_5 = []

with open("data/IM_0005-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_5.append(float(line.split()[0]))
        y_5.append(float(line.split()[1]))
        curve.append(point)
#plotting the plot
plt.style.use('seaborn')
plt.title("Apical Image(SAX) - IM_0003")
plt.plot(x_5, y_5)
plt.plot((x_5[0], x_5[len(x_5)-1]), (y_5[0], y_5[len(y_5)-1]))

# %% [markdown]
# # A4C

# %%
x_8 = []
y_8 = []
plt.style.use('seaborn')
with open("data/IM_0008-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_8.append(float(line.split()[0]))
        y_8.append(float(line.split()[1]))
    
#plotting the output
plt.style.use('seaborn')
plt.title("A4C Image(LAX) - IM_0008")
plt.plot(x_8, y_8)
plt.plot((x_8[0], x_8[len(x_8)-1]), (y_8[0], y_8[len(y_8)-1]))

# %% [markdown]
# # A2C

# %%
#% inline matplotlib
from matplotlib import pyplot as plt
import numpy as np
from matplotlib import transforms
curve = []
x_13 = []
y_13 = []
plt.style.use('seaborn')
with open("data/IM_0013-01_inx.txt", "r") as file:
    for line in file:
        point = line.split()
        x_13.append(float(line.split()[0]))
        y_13.append(float(line.split()[1]))
        curve.append(point)
# plotting the output
plt.style.use('seaborn')
plt.title("A2C Image(LAX) - IM_0013")
plt.plot(x_13, y_13)
plt.plot((x_13[0], x_13[len(x_13)-1]), (y_13[0], y_13[len(y_13)-1]))
